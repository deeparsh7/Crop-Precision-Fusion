# %%
import pandas as pd
import numpy as np
import warnings
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('crop_recommendation_test.csv')
df
# Out:
#      Unnamed: 0    N   P   K  temperature   humidity        ph    rainfall   y
# 0            99   65  37  40    23.359054  83.595123  5.333323  188.413665  20
# 1          1337  117  27  48    26.532593  82.390540  6.835268   54.306608  21
# 2           316   22  79  17    21.424511  20.396597  5.912290  116.520692   9
# 3           985   39  25  36    18.902230  94.998975  5.567805  107.610321  19
# 4           471    5  77  19    31.085650  66.688330  6.242052  175.930327  18
# ..          ...  ...  ..  ..          ...        ...       ...         ...  ..
# 215        1708   38  68  54    29.337105  90.817814  6.739170  202.057275  17
# 216         275   27  79  82    17.065793  17.540241  6.307005   70.871506   3
# 217        1868    8  26  26    25.547599  91.641948  5.702485  212.867626   4
# 218         721   25  71  24    28.495387  60.448484  7.187722   74.915595   2
# 219        1151   21  31  32    35.385987  51.426642  5.254532   90.296439  12
#
# [220 rows x 9 columns]

# %%
df_train, df_test, y_train, y_test = train_test_split(df.iloc[:,1:-1], df.iloc[:,-1], test_size=0.2, random_state=42)

# %%
df_test
# Out:
#        N    P    K  temperature   humidity        ph    rainfall
# 132   17   18   43    24.488084  90.836872  5.843005  103.196934
# 148   98   44   21    25.771751  74.089114  6.524478  107.493192
# 93   112   39   29    26.124922  63.374792  6.726529  147.803530
# 180   63   58   22    18.254054  55.282204  6.204748   63.723582
# 15    95   82   48    27.394896  83.311720  5.719015   92.781336
# 115   90   16   45    24.920933  80.617508  6.291540   50.557108
# 172    0   65   24    28.495844  62.446162  7.841496   53.145310
# 209   37   57   20    31.100625  44.820692  7.354287   70.799345
# 75    47   79   78    17.483954  14.760145  6.609697   65.113656
# 142   93   56   36    24.014976  82.056872  6.984354  185.277339
# 100    1   15    9    29.983647  94.552397  7.533509  115.356032
# 30    49   69   82    18.315615  15.361435  7.263119   81.787105
# 190   17   74   17    26.030270  69.558631  7.393211   37.113958
# ...

# %%
df_train
# Out:
#        N    P    K  temperature   humidity        ph    rainfall
# 79    71   54   16    22.613600  63.690706  5.749914   87.759539
# 217    8   26   26    25.547599  91.641948  5.702485  212.867626
# 113   38  132  197    20.420948  81.541850  5.931102   66.930657
# 140   86    6   53    25.920302  83.472026  6.921848   42.106815
# 122   40   73   20    21.593430  20.318712  5.811314   61.138720
# ..   ...  ...  ...          ...        ...       ...         ...
# 106  133   57   19    23.542347  75.982033  7.947011   84.125367
# 14   117   19   55    28.803119  91.783369  6.121745   25.163599
# 92    24   37   21    30.573999  58.226868  5.818219   62.748038
# 179  101   25   52    29.099104  94.222378  6.750146   22.524973
# 102   61   59   17    23.338446  59.245806  6.474443  105.008314
#
# [176 rows x 7 columns]

# %%
y_test
# Out:
# 132    19
# 148    11
# 93      5
# 180    11
# 15      1
# 115    21
# 172    10
# 209    13
# 75      3
# 142    20
# 100    16
# 30      3
# 190    10
# 9      16
# 67      5
# 218     2
# 175     8
# 18      1
# 197    19
# 66      8
# 189     4
# 96      9
# 210     7
# 25     19
# 127     8
# 201     4
# 97     14
# 16      2
# 45     10
# 154     3
# 111    17
# 55     15
# 108     6
# 196    21
# 73      3
# 109     4
# 82     11
# 138    12
# 141    15
# 101    12
# 86     11
# 193    14
# 120     8
# 95     17
# Name: y, dtype: int64

# %%
y_train
# Out:
# 79     11
# 217     4
# 113     7
# 140    21
# 122     9
#        ..
# 106     6
# 14     15
# 92     13
# 179    15
# 102    11
# Name: y, Length: 176, dtype: int64

# %%
model = RandomForestClassifier()
model.fit(df_train, y_train)
# Out:
# RandomForestClassifier()

# %%
pred = model.predict(df_test)
actual = np.array(y_test)
actual
# Out:
# array([19, 11,  5, 11,  1, 21, 10, 13,  3, 20, 16,  3, 10, 16,  5,  2,  8,
#         1, 19,  8,  4,  9,  7, 19,  8,  4, 14,  2, 10,  3, 17, 15,  6, 21,
#         3,  4, 11, 12, 15, 12, 11, 14,  8, 17], dtype=int64)

# %%
print("Accuracy:", model.score(df_test, y_test))
# Out:
# Accuracy: 0.9545454545454546

# %%
label_name = pd.read_csv('label_name_number.csv').iloc[:,1:]
label_name
# Out:
#       crop_name  Crop_number
# 0         apple            0
# 1        banana            1
# 2     blackgram            2
# 3      chickpea            3
# 4       coconut            4
# 5        coffee            5
# 6        cotton            6
# 7        grapes            7
# 8          jute            8
# 9   kidneybeans            9
# 10       lentil           10
# 11        maize           11
# 12        mango           12
# 13    mothbeans           13
# 14     mungbean           14
# 15    muskmelon           15
# 16       orange           16
# 17       papaya           17
# 18   pigeonpeas           18
# 19  pomegranate           19
# 20         rice           20
# 21   watermelon           21

# %%
sample_idx = np.random.randint(0, len(df_test))
res = model.predict([df_test.iloc[1].tolist()])
print(int(res))
if int(res) in label_name['Crop_number'].values:
    index_number = label_name.index[label_name['Crop_number'] == int(res)].tolist()[0]
    crop_name = label_name['crop_name'].iloc[index_number]
    print("crop_name:-> ", crop_name)
# Out:
# 11
# crop_name:->  maize
